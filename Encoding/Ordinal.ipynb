# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

# %%
data = {
    "name":["A","C","D","B","E","A","E","C"],
    "dept_id":["s1","s4","s5","s2","s3","s1","s4","s5"],
    "d_name" :["Analyst","Developer","Engineer","Trainer","UI Developer","Developer","Engineer","Analyst"],
    "salary" :[15000,20000,23000,18000,21000,19000,25000,27000]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   name dept_id        d_name  salary
# 0    A      s1       Analyst   15000
# 1    C      s4     Developer   20000
# 2    D      s5      Engineer   23000
# 3    B      s2       Trainer   18000
# 4    E      s3  UI Developer   21000
# 5    A      s1     Developer   19000
# 6    E      s4      Engineer   25000
# 7    C      s5       Analyst   27000

# %%
x = df.drop(columns='salary')
y = df['salary']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
df
# Out:
#   name dept_id        d_name  salary
# 0    A      s1       Analyst   15000
# 1    C      s4     Developer   20000
# 2    D      s5      Engineer   23000
# 3    B      s2       Trainer   18000
# 4    E      s3  UI Developer   21000
# 5    A      s1     Developer   19000
# 6    E      s4      Engineer   25000
# 7    C      s5       Analyst   27000

# %% [markdown]
# # Scenario 1
#
# * Error --> ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,)

# %%
encoder = OrdinalEncoder(categories=[['Developer','Analyst','Enginneer','Trainer',"UI Developer"],["s1",'s2','s5','s4','s3']],
                         handle_unknown="use_encoded_value",
                         unknown_value=-1
                         )

encoder.fit_transform(xtrain[['d_name','dept_id']])
# encoder.fit_transform(xtrain[['d_name','dept_id',"name"]])

#Error --> ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,)
# Out:
# array([[ 1.,  0.],
#        [ 1.,  2.],
#        [-1.,  2.],
#        [ 4.,  4.],
#        [ 3.,  1.],
#        [-1.,  3.]])

# %% [markdown]
# # Scenario 2
#
# * InvalidIndexError: (['dept_id'], ['d_name'])
# * Every value is unknown now! So ,it assigns -1 for all the values.

# %%
encoder = OrdinalEncoder(categories=[['Developer','Analyst','Enginneer','Trainer',"UI Developer"],["s1",'s2','s5','s4','s3']],
                         handle_unknown="use_encoded_value",
                         unknown_value=-1
                         )

encoder.fit_transform(xtrain[['dept_id'],['d_name']])
# encoder.fit_transform(xtrain[['dept_id','d_name']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:174, in pandas._libs.index.IndexEngine.get_loc()
# --> 174 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: '(['dept_id'], ['d_name'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[58], line 6
#       2                          handle_unknown="use_encoded_value",
#       3                          unknown_value=-1
#       4                          )
#       5
# ----> 6 encoder.fit_transform(xtrain[['dept_id'],['d_name']])
#       7 # encoder.fit_transform(xtrain[['dept_id','d_name']])
#
# File c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
# -> 3653     self._check_indexing_error(key)
#    3654     raise
#
# File c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:6094, in Index._check_indexing_error(self, key)
#    6090 def _check_indexing_error(self, key) -> None:
#    6091     if not is_scalar(key):
#    6092         # if key is not a scalar, directly raise an error (the code below
#    6093         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6094         raise InvalidIndexError(key)
#
# InvalidIndexError: (['dept_id'], ['d_name'])

# %% [markdown]
# # Scenario 3
#
# * If the value on the Category present it gives a meaningful value if not present it gives (-1)

# %%
encoder = OrdinalEncoder(categories=[['Developer','Analyst','Enginneer','AI Engineer'],["s1",'s2','s5','s4','s3']],
                         handle_unknown="use_encoded_value",
                         unknown_value=-1
                         )

encoder.fit_transform(xtrain[['d_name','dept_id']])
# Out:
# array([[ 1.,  0.],
#        [ 1.,  2.],
#        [-1.,  2.],
#        [-1.,  4.],
#        [-1.,  1.],
#        [-1.,  3.]])
