# %%
# %pip install -r ../requirements.txt
# Out:
# Collecting category_encoders==2.10.0 (from -r ../requirements.txt (line 1))
#   Using cached category_encoders-2.10.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting pandas==3.0.5 (from -r ../requirements.txt (line 2))
#   Using cached pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy==2.5.1 in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from -r ../requirements.txt (line 3)) (2.5.1)
# Requirement already satisfied: scikit-learn==1.9.0 in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from -r ../requirements.txt (line 4)) (1.9.0)
# Collecting statsmodels==0.14.6 (from -r ../requirements.txt (line 5))
#   Using cached statsmodels-0.14.6-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# Collecting patsy>=0.5.1 (from category_encoders==2.10.0->-r ../requirements.txt (line 1))
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: scipy>=1.0.0 in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from category_encoders==2.10.0->-r ../requirements.txt (line 1)) (1.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas==3.0.5->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas==3.0.5->-r ../requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn==1.9.0->-r ../requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn==1.9.0->-r ../requirements.txt (line 4)) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn==1.9.0->-r ../requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from statsmodels==0.14.6->-r ../requirements.txt (line 5)) (26.2)
# Requirement already satisfied: six>=1.5 in c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas==3.0.5->-r ../requirements.txt (line 2)) (1.17.0)
# Using cached category_encoders-2.10.0-py3-none-any.whl (87 kB)
# Using cached pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
# Using cached statsmodels-0.14.6-cp314-cp314-win_amd64.whl (9.6 MB)
# Using cached patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, pandas, statsmodels, category_encoders
#
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#    ---------------------------------------- 0/4 [patsy]
#   Attempting uninstall: pandas
#    ---------------------------------------- 0/4 [patsy]
#     Found existing installation: pandas 3.0.3
#    ---------------------------------------- 0/4 [patsy]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#     Uninstalling pandas-3.0.3:
#    ---------- ----------------------------- 1/4 [pandas]
#       Successfully uninstalled pandas-3.0.3
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    ---------- ----------------------------- 1/4 [pandas]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    ------------------------------ --------- 3/4 [category_encoders]
#    ------------------------------ --------- 3/4 [category_encoders]
#    ------------------------------ --------- 3/4 [category_encoders]
#    ------------------------------ --------- 3/4 [category_encoders]
#    ---------------------------------------- 4/4 [category_encoders]
#
# Successfully installed category_encoders-2.10.0 pandas-3.0.5 patsy-1.0.2 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages\~andas'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from category_encoders import TargetEncoder

# %%
data = {
    # "Dept":["ML","DL","DL","Ml","DL","ML","DL","DL","Ml","DL"],
    "City" : ["Banglore","Vellore","Chennai","Banglore","Madurai","Banglore","Vellore","Chennai","Banglore","Madurai"],
    "Product" : ["Mobile","Clothing","Sandals","Electronics","Clothing","Sandals","Mobile","Clothing","Appliances","Furnichers"],
    "Price" : [2000,1000,4000,3000,1000,2000,1000,4000,3000,1000]
}

# %%
df = pd.DataFrame(data)

# %%
encoder = TargetEncoder()
