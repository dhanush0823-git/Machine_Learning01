# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.DataFrame({
    "Prd_id" : [1001,1002,1003,1004],
    "Colour" : ["Red","Blue","Blue","Red"]
    # "Product" : ["Wood","Plastic","Wood","Plastic"]
})

# %%
x = df.drop(columns='Prd_id')
y = df['Colour']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
encoder = LabelEncoder()
encoder.fit_transform(xtrain)
# Out:
# c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\preprocessing\_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
xtest = encoder.transform(xtest)
# Out:
# c:\Users\dhanu\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\preprocessing\_label.py:139: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
xtest
# Out:
# array([0])

# %%
xtrain
# Out:
# array([1, 1, 0])
