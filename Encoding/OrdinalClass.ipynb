# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.DataFrame({
    "name":["A","C","D","B","E","A","E","C"],
    "dept_id":["s1","s4","s5","s2","s3","s1","s4","s5"],
    "d_name" :["Analyst","Developer","Engineer","Trainer","UI Developer","Developer","Engineer","Analyst"]
})

# %%
x = df.drop(columns='d_name')
y = df['d_name']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
'''
encoder = OrdinalEncoder(categories=[['name']])
encoder.fit_transform(xtrain)

ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,)
'''
# Out:
# "\nencoder = OrdinalEncoder(categories=[['name']])\nencoder.fit_transform(xtrain)\n\nValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,)\n"

# %%
df['name'].unique()
# Out:
# <ArrowStringArray>
# ['A', 'C', 'D', 'B', 'E']
# Length: 5, dtype: str

# %%
'''
encoder = OrdinalEncoder(categories=[['D', 'B', 'E', 'C','F' ]])
encoder.fit_transform(xtrain[['name']])

ValueError: Found unknown categories ['A'] in column 0 during fit

['D', 'B', 'E', 'A','F','C]
# If the value in the column is present in the in the original column it accepts all the values in unknwon values it ignores 
'''
# Out:
# "\nencoder = OrdinalEncoder(categories=[['D', 'B', 'E', 'C','F' ]])\nencoder.fit_transform(xtrain[['name']])\n\nValueError: Found unknown categories ['A'] in column 0 during fit\n\n['D', 'B', 'E', 'A','F','C]\n# If the value in the column is present in the in the original column it accepts all the values in unknwon values it ignores \n"

# %%
'''
encoder = OrdinalEncoder(categories=[['D', 'B', 'E', 'A','F']],handle_unknown="use_encoded_value")
encoder.fit_transform(xtrain[['name']])

TypeError: unknown_value should be an integer or np.nan when handle_unknown is 'use_encoded_value', got None.


'''
# Out:
# '\nencoder = OrdinalEncoder(categories=[[\'D\', \'B\', \'E\', \'A\',\'F\']],handle_unknown="use_encoded_value")\nencoder.fit_transform(xtrain[[\'name\']])\n\nTypeError: unknown_value should be an integer or np.nan when handle_unknown is \'use_encoded_value\', got None.\n\n\n'

# %%
df['dept_id'].unique()
# Out:
# <ArrowStringArray>
# ['s1', 's4', 's5', 's2', 's3']
# Length: 5, dtype: str

# %%
'''
encoder = OrdinalEncoder(categories=[['D', 'B', 'E', 'A','F'],['s1', 's4', 's5', 's2', 's3']],handle_unknown="use_encoded_value",unknown_value=-1)
encoder.fit_transform(xtrain[['name']])

ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).
'''
# Out:
# '\nencoder = OrdinalEncoder(categories=[[\'D\', \'B\', \'E\', \'A\',\'F\'],[\'s1\', \'s4\', \'s5\', \'s2\', \'s3\']],handle_unknown="use_encoded_value",unknown_value=-1)\nencoder.fit_transform(xtrain[[\'name\']])\n\nValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).\n'

# %%
encoder = OrdinalEncoder(categories=[['D', 'B', 'E', 'A','F'],['s1', 's4', 's5', 's2', 's3']],handle_unknown="use_encoded_value",unknown_value=-1)
encoder.fit_transform(xtrain,ytrain)
# Out:
# array([[ 3.,  0.],
#        [-1.,  2.],
#        [ 0.,  2.],
#        [ 2.,  4.],
#        [ 1.,  3.],
#        [ 2.,  1.]])

# %%
encoder.transform(xtest)
# Out:
# array([[-1.,  1.],
#        [ 3.,  0.]])
