# %%
from sklearn.preprocessing import StandardScaler,RobustScaler,MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('standardscaler_.csv')

# %%
df.head()
# Out:
#    Experience_Years    Age  Education_Level  Hours_Per_Week     Salary
# 0              5.99  34.63                3           41.12   87638.54
# 1              4.72  39.55                4           46.82   84956.80
# 2              6.30  23.01                1           40.63   73501.52
# 3              8.05  32.81                4           37.85  100707.27
# 4              4.53  26.75                3           40.61   80094.46

# %%
df.corr()
# Out:
#                   Experience_Years       Age  Education_Level  Hours_Per_Week  \
# Experience_Years          1.000000 -0.073255        -0.071472        0.060724
# Age                      -0.073255  1.000000        -0.004516        0.047329
# Education_Level          -0.071472 -0.004516         1.000000        0.006592
# Hours_Per_Week            0.060724  0.047329         0.006592        1.000000
# Salary                    0.514034 -0.010178         0.323822        0.083765
#
#                     Salary
# Experience_Years  0.514034
# Age              -0.010178
# Education_Level   0.323822
# Hours_Per_Week    0.083765
# Salary            1.000000

# %%
x = df.drop(columns='Salary')
y = df['Salary']

# %%
sns.boxplot(x)
# Out:
# <Axes: >

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
standard_scaler = StandardScaler()
min_max_scaler = MinMaxScaler()

# %%
xtrain[['Experience_Years','Age','Hours_Per_Week']] = standard_scaler.fit_transform(xtrain[['Experience_Years','Age','Hours_Per_Week']])

# %%
xtrain
# Out:
#      Experience_Years       Age  Education_Level  Hours_Per_Week
# 249          0.410116 -1.487863                1        0.525855
# 433          0.731716 -2.318167                3       -0.909748
# 19          -1.442912  0.774504                4        0.217080
# 322         -0.840550  2.395274                1        1.163455
# 332          0.073202 -1.066421                2        0.078733
# ..                ...       ...              ...             ...
# 106          1.921126 -0.825298                4        0.475729
# 270          1.466802  0.728377                3       -1.260629
# 348         -0.738455 -0.682720                1       -1.062131
# 435          0.073202 -0.540143                1        0.970972
# 102         -0.355598  0.898211                4       -0.731300
#
# [400 rows x 4 columns]

# %%
xtrain[['Experience_Years','Age','Hours_Per_Week','Education_Level']] = standard_scaler.fit_transform(xtrain[['Experience_Years','Age','Hours_Per_Week','Education_Level']])

# %%
xtrain['Experience_Years'].mean()
# Out:
# np.float64(-8.881784197001253e-18)

# %%
xtrain['Experience_Years'].std()
# Out:
# np.float64(1.0012523486435176)

# %%
xtrain['Age'].mean()
# Out:
# np.float64(4.440892098500626e-18)

# %%
xtrain['Age'].std()
# Out:
# np.float64(1.0012523486435179)

# %%
xtrain['Education_Level'] = min_max_scaler.fit_transform(xtrain[['Education_Level']])

# %%
xtrain
# Out:
#      Experience_Years       Age  Education_Level  Hours_Per_Week
# 249          0.410116 -1.487863         0.000000        0.525855
# 433          0.731716 -2.318167         0.666667       -0.909748
# 19          -1.442912  0.774504         1.000000        0.217080
# 322         -0.840550  2.395274         0.000000        1.163455
# 332          0.073202 -1.066421         0.333333        0.078733
# ..                ...       ...              ...             ...
# 106          1.921126 -0.825298         1.000000        0.475729
# 270          1.466802  0.728377         0.666667       -1.260629
# 348         -0.738455 -0.682720         0.000000       -1.062131
# 435          0.073202 -0.540143         0.000000        0.970972
# 102         -0.355598  0.898211         1.000000       -0.731300
#
# [400 rows x 4 columns]

# %%
xtest[['Experience_Years','Age','Hours_Per_Week','Education_Level']] = standard_scaler.transform(xtest[['Experience_Years','Age','Hours_Per_Week','Education_Level']])

# %%
xtest
# Out:
#      Experience_Years    Age  Education_Level  Hours_Per_Week
# 361              8.07  22.42        -0.438701           38.64
# 73               8.13  28.90        -1.338600           43.05
# 374              9.31  29.83        -1.338600           41.47
# 155              3.57  30.30        -1.338600           43.80
# 104              4.68  32.07         1.361098           39.13
# ..                ...    ...              ...             ...
# 347              2.19  42.28        -1.338600           42.34
# 86               6.83  27.70         0.461198           36.07
# 75               6.64  18.94         1.361098           38.42
# 438              1.59  31.22         0.461198           35.22
# 15               3.88  33.78        -1.338600           44.47
#
# [100 rows x 4 columns]

# %%
xtrain
# Out:
#      Experience_Years       Age  Education_Level  Hours_Per_Week
# 249          0.410116 -1.487863         0.000000        0.525855
# 433          0.731716 -2.318167         0.666667       -0.909748
# 19          -1.442912  0.774504         1.000000        0.217080
# 322         -0.840550  2.395274         0.000000        1.163455
# 332          0.073202 -1.066421         0.333333        0.078733
# ..                ...       ...              ...             ...
# 106          1.921126 -0.825298         1.000000        0.475729
# 270          1.466802  0.728377         0.666667       -1.260629
# 348         -0.738455 -0.682720         0.000000       -1.062131
# 435          0.073202 -0.540143         0.000000        0.970972
# 102         -0.355598  0.898211         1.000000       -0.731300
#
# [400 rows x 4 columns]
