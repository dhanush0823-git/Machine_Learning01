# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import numpy as np

# %%
df = pd.DataFrame( {
    "d_id" : [101,np.nan,103,104,np.nan],
    "age" : [22,23,np.nan,np.nan,24],
    "name" : ["Vijay","Dhanush",np.nan,"Surya",np.nan]})

# %%
# imputer = SimpleImputer(
#     strategy = "constant",fill_value = 0)

# %%
imputer = SimpleImputer(
    strategy = "most_frequent")

# %%
imputer.fit_transform(df[['d_id','age','name']]) # we'll use xtrain in fit_transform always
# Out:
# array([[101.0, 22.0, 'Vijay'],
#        [101.0, 23.0, 'Dhanush'],
#        [103.0, 22.0, 'Dhanush'],
#        [104.0, 22.0, 'Surya'],
#        [101.0, 24.0, 'Dhanush']], dtype=object)
