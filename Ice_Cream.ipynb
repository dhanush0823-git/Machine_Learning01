# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Ice_cream selling data.csv')

# %%
df.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
covariance = df.cov()
covariance
# Out:
#                          Temperature (°C)  Ice Cream Sales (units)
# Temperature (°C)                 7.277432                -5.796162
# Ice Cream Sales (units)         -5.796162               150.422433

# %%
df.columns
# Out:
# Index(['Temperature (°C)', 'Ice Cream Sales (units)'], dtype='str')

# %%
correlation = df.corr()
correlation
# Out:
#                          Temperature (°C)  Ice Cream Sales (units)
# Temperature (°C)                 1.000000                -0.175184
# Ice Cream Sales (units)         -0.175184                 1.000000

# %%
sns.scatterplot(df,x='Temperature (°C)',y='Ice Cream Sales (units)')
# Out:
# <Axes: xlabel='Temperature (°C)', ylabel='Ice Cream Sales (units)'>
